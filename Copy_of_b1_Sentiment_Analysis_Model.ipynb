# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanushmarusamy/FOODS/blob/main/Copy_of_b1_Sentiment_Analysis_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/1_LiveProjects/Project2_Sentiment_Analysis
# !ls
# Out:
# /content/drive/MyDrive/1_LiveProjects/Project2_Sentiment_Analysis
# a1_RestaurantReviews_HistoricDump.tsv  c1_BoW_Sentiment_Model.pkl
# a2_RestaurantReviews_FreshDump.tsv     c2_Classifier_Sentiment_Model
# b1_Sentiment_Analysis_Model.ipynb      c3_Predicted_Sentiments_Fresh_Dump.tsv
# b2_Sentiment_Predictor.ipynb	       d_Business_Deck_Sentiment_Analysis.pdf

# %%
dataset = pd.read_csv("kalki_movie_reviews.csv")

# %%
dataset.shape
# Out:
# (4990, 2)

# %%
dataset.head()
# Out:
#                                             Comments  Ratings
# 0  I didnt go in with big hopes, but i was expect...      8.0
# 1  A unique genre, a well written story (script) ...      8.0
# 2  Majestic at scale, grandeur in VFX, and great ...      9.0
# 3  "Kalki 2898" is not just a movie; it's an expe...     10.0
# 4  Best Indian movie Nagi combined Hindu mytholog...     10.0

# %% [markdown]
# ### Data Preprocessing

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus = []

# Convert the 'Comments' column to string type to handle any non-string entries (e.g., NaN)
dataset['Comments'] = dataset['Comments'].astype(str)

for i in range(min(900, len(dataset))):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Comments'].iloc[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in all_stopwords]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# []

# %% [markdown]
# ### Data transformation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1420)

# %%
X = cv.fit_transform(corpus).toarray()
# Assuming sentiment is derived from 'Ratings' column:
# Ratings >= 7.0 are considered positive (1), otherwise negative (0)
y = (dataset['Ratings'].iloc[:len(corpus)] >= 7.0).astype(int).values

# %%
# Saving BoW dictionary to later use in prediction
import pickle
bow_path = 'c1_BoW_Sentiment_Model.pkl'
pickle.dump(cv, open(bow_path, "wb"))

# %% [markdown]
# ### Dividing dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (900, 1134)
# Shape of y: (4990,)

# %%
display(dataset.head())
# Out:
#                                             Comments  Ratings
# 0  I didnt go in with big hopes, but i was expect...      8.0
# 1  A unique genre, a well written story (script) ...      8.0
# 2  Majestic at scale, grandeur in VFX, and great ...      9.0
# 3  "Kalki 2898" is not just a movie; it's an expe...     10.0
# 4  Best Indian movie Nagi combined Hindu mytholog...     10.0

# %%
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

# %%
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")

# %% [markdown]
# ### Model fitting (Naive Bayes)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
print('Missing values in each column:')
display(dataset.isnull().sum())
# Out:
# Missing values in each column:
# Comments       0
# Ratings     4934
# dtype: int64

# %%
# Exporting NB Classifier to later use in prediction
import joblib
joblib.dump(classifier, 'c2_Classifier_Sentiment_Model')
# Out:
# ['c2_Classifier_Sentiment_Model']

# %% [markdown]
# ###Model performance

# %%
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[171   0]
#  [  0   9]]
# 1.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[171   0]
#  [  0   9]]
# 1.0
